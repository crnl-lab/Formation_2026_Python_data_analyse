# %% [markdown]
# # Statsmodel formula

# %% [markdown]
# # import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import statsmodels.api as sm

# %% [markdown]
# # load data

# %% [markdown]
# Data from A.-M. Guerry, "Essay on the Moral Statistics of France"
# Description
#
# Andre-Michel Guerry (1833) was the first to systematically collect and analyze social data on such things as crime, literacy and suicide with the view to determining social laws and the relations among these variables.
#
# The Guerry data frame comprises a collection of 'moral variables' on the 86 departments of France around 1830. A few additional variables have been added from other sources.
#
# https://vincentarelbundock.github.io/Rdatasets/doc/HistData/Guerry.html

# %%
open_path = os.path.join(os.getcwd(), 'data', 'Guerry.csv')
df_raw = pd.read_csv(open_path)
df_raw
# Out:
#     Unnamed: 0  dept Region    Department  Crime_pers  Crime_prop  Literacy  \
# 0            1     1      E           Ain       28870       15890        37
# 1            2     2      N         Aisne       26226        5521        51
# 2            3     3      C        Allier       26747        7925        13
# 3            4     4      E  Basses-Alpes       12935        7289        46
# 4            5     5      E  Hautes-Alpes       17488        8174        69
# ..         ...   ...    ...           ...         ...         ...       ...
# 81          82    86      W        Vienne       15010        4710        25
# 82          83    87      C  Haute-Vienne       16256        6402        13
# 83          84    88      E        Vosges       18835        9044        62
# 84          85    89      C         Yonne       18006        6516        47
# 85          86   200    NaN         Corse        2199        4589        49
#
#     Donations  Infants  Suicides  ... Crime_parents  Infanticide  \
# 0        5098    33120     35039  ...            71           60
# 1        8901    14572     12831  ...             4           82
# 2       10973    17044    114121  ...            46           42
# 3        2733    23018     14238  ...            70           12
# 4        6962    23076     16171  ...            22           23
# ..        ...      ...       ...  ...           ...          ...
# 81       8922    35224     21851  ...            20            1
# 82      13817    19940     33497  ...            68            6
# 83       4040    14978     33029  ...            58           34
# 84       4276    16616     12789  ...            32           22
# 85      37015    24743     37016  ...            81            2
#
#     Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# 0                69       41         55           46           13   218.372
# 1                36       38         82           24          327    65.945
# 2                76       66         16           85           34   161.927
# 3                37       80         32           29            2   351.399
# 4                64       79         35            7            1   320.280
# ..              ...      ...        ...          ...          ...       ...
# 81               44       40         38           65           18   170.523
# 82               78       55         11           84            7   198.874
# 83                5       14         85           11           43   174.477
# 84               35       51         66           27          272    81.797
# 85               84       83          9           25            1   539.213
#
#     Area  Pop1831
# 0   5762   346.03
# 1   7369   513.00
# 2   7340   298.26
# 3   6925   155.90
# 4   5549   129.10
# ..   ...      ...
# 81  6990   282.73
# 82  5520   285.13
# 83  5874   397.99
# 84  7427   352.49
# 85  8680   195.41
#
# [86 rows x 24 columns]

# %%
df_raw.columns
# Out:
# Index(['Unnamed: 0', 'dept', 'Region', 'Department', 'Crime_pers',
#        'Crime_prop', 'Literacy', 'Donations', 'Infants', 'Suicides',
#        'MainCity', 'Wealth', 'Commerce', 'Clergy', 'Crime_parents',
#        'Infanticide', 'Donation_clergy', 'Lottery', 'Desertion', 'Instruction',
#        'Prostitutes', 'Distance', 'Area', 'Pop1831'],
#       dtype='str')

# %%
df = df_raw[['Lottery', 'Literacy', 'Wealth', 'Region']].dropna()
df
# Out:
#     Lottery  Literacy  Wealth Region
# 0        41        37      73      E
# 1        38        51      22      N
# 2        66        13      61      C
# 3        80        46      76      E
# 4        79        69      83      E
# ..      ...       ...     ...    ...
# 80       68        28      56      W
# 81       40        25      68      W
# 82       55        13      67      C
# 83       14        62      82      E
# 84       51        47      30      C
#
# [85 rows x 4 columns]

# %% [markdown]
# # Formules à la sauce R = Wilkinson Notation
#
#
# Voir **pasty** https://patsy.readthedocs.io/en/latest/formulas.html

# %%
import statsmodels.formula.api as smf

##avec un ~ pour definir qui en fonction de qui
my_formula = "Lottery ~ Literacy"


### on definit la regression : ols = Ordinary Least Square pour optimiser la regression linaire
### (c'est le modele de regression dans R également)
mod = smf.ols(formula=my_formula, data=df)

### on estime (fit) le model
res_ols = mod.fit()
print (res_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     14.16
# Date:                Wed, 11 Mar 2026   Prob (F-statistic):           0.000312
# Time:                        10:28:28   Log-Likelihood:                -386.13
# No. Observations:                  85   AIC:                             776.3
# Df Residuals:                      83   BIC:                             781.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     64.2389      6.163     10.423      0.000      51.981      76.497
# Literacy      -0.5417      0.144     -3.763      0.000      -0.828      -0.255
# ==============================================================================
# Omnibus:                        7.455   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                2.936
# Skew:                           0.061   Prob(JB):                        0.230
# Kurtosis:                       2.098   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.regplot(data=df, x="Lottery", y="Literacy")
# Out:
# <Axes: xlabel='Lottery', ylabel='Literacy'>

# %%
##pour definir un modele avec plusieurs variables, on utilise le '+'
my_full_formula = "Lottery ~ Literacy + Wealth"

full_mod = smf.ols(formula=my_full_formula, data=df)

### on estime (fit) le model
full_res_ols = full_mod.fit()
print (full_res_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     18.32
# Date:                Wed, 11 Mar 2026   Prob (F-statistic):           2.66e-07
# Time:                        10:28:29   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             760.3
# Df Residuals:                      82   BIC:                             767.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.7979      7.873      5.055      0.000      24.135      55.460
# Literacy      -0.3780      0.136     -2.790      0.007      -0.648      -0.108
# Wealth         0.4138      0.094      4.398      0.000       0.227       0.601
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.294
# Skew:                          -0.335   Prob(JB):                        0.193
# Kurtosis:                       2.307   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
##pour definir un modele avec plusieurs variables, on utilise le '+'
my_full_formula = "Lottery ~ Literacy * Wealth"

full_mod = smf.ols(formula=my_full_formula, data=df)

### on estime (fit) le model
full_res_ols = full_mod.fit()
print (full_res_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     12.06
# Date:                Wed, 11 Mar 2026   Prob (F-statistic):           1.32e-06
# Time:                        10:28:29   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             762.3
# Df Residuals:                      81   BIC:                             772.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          38.6348     15.825      2.441      0.017       7.149      70.121
# Literacy           -0.3522      0.334     -1.056      0.294      -1.016       0.312
# Wealth              0.4364      0.283      1.544      0.126      -0.126       0.999
# Literacy:Wealth    -0.0005      0.006     -0.085      0.933      -0.013       0.012
# ==============================================================================
# Omnibus:                        4.447   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.108   Jarque-Bera (JB):                3.228
# Skew:                          -0.332   Prob(JB):                        0.199
# Kurtosis:                       2.314   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Rq: on peut aussi specifier TOUTES les interactions que l'on veut tester en mettant
# my_formula = "Lottery ~ Literacy + Region + Literacy:Region + Wealth +  Wealth:Region + Literacy:Wealth + Literacy:Wealth:Region"
#
# ceci revient au meme que 'Literacy * Wealth * Region'

# %% [markdown]
# ### ANOVA simple

# %%
anova_model = smf.ols("Lottery ~ Region", data=df).fit()
anova_results = sm.stats.anova_lm(anova_model, typ=2)
print(anova_results)
# Out:
#                 sum_sq    df         F    PR(>F)
# Region     7307.011765   4.0  3.312945  0.014534
# Residual  44111.882353  80.0       NaN       NaN

# %%
tukey = sm.stats.multicomp.pairwise_tukeyhsd(endog=df["Lottery"], groups=df["Region"], alpha=0.05)
print("\nTukey HSD Results:")
print(tukey)

tukey.plot_simultaneous()
# Out:
# Tukey HSD Results:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      C      E -18.7059 0.1485  -41.185  3.7732  False
#      C      N -25.7647 0.0165 -48.2438 -3.2856   True
#      C      S  -5.7647 0.9523 -28.2438 16.7144  False
#      C      W  -8.4118 0.8339 -30.8908 14.0673  False
#      E      N  -7.0588 0.9047 -29.5379 15.4202  False
#      E      S  12.9412 0.4976  -9.5379 35.4202  False
#      E      W  10.2941 0.7053  -12.185 32.7732  False
#      N      S     20.0 0.1048  -2.4791 42.4791  False
#      N      W  17.3529 0.2078  -5.1261  39.832  False
#      S      W  -2.6471 0.9974 -25.1261  19.832  False
# -----------------------------------------------------

# %% [markdown]
# # LMM (linear mixed model)

# %%
sns.lmplot(data=df_raw, x="Wealth", y="Instruction", hue="Region", aspect=2, height=6, logistic=False)

# %%
df_raw = df_raw.dropna()
# Syntaxe pour un modèle à effets mixtes avec effet aléatoire sur 'Region'
mixed_mod = smf.mixedlm("Instruction ~ Wealth", data=df_raw, groups=df["Region"])
mixed_res = mixed_mod.fit()
print(mixed_res.summary())
# Out:
#           Mixed Linear Model Regression Results
# =========================================================
# Model:            MixedLM Dependent Variable: Instruction
# No. Observations: 85      Method:             REML
# No. Groups:       5       Scale:              271.3473
# Min. group size:  17      Log-Likelihood:     -364.2459
# Max. group size:  17      Converged:          Yes
# Mean group size:  17.0
# ----------------------------------------------------------
#             Coef.   Std.Err.    z    P>|z|  [0.025  0.975]
# ----------------------------------------------------------
# Intercept   34.451     9.420  3.657  0.000  15.988  52.915
# Wealth       0.204     0.079  2.594  0.009   0.050   0.358
# Group Var  369.023    16.957
# =========================================================

# %% [markdown]
# # simulation

# %%
def generate_habitants_data(n=300, seed=42):
    np.random.seed(seed)

    villes = ['toulouse', 'lyon', 'paris', 'montpellier', 'neuilly']
    df = pd.DataFrame()
    df['ville'] = np.random.choice(villes, size=n)

    # Mappings pour effets simulés
    bolas_base = {
        'neuilly': 20,
        'paris': 35,
        'lyon': 50,
        'montpellier': 65,
        'toulouse': 80
    }

    classe_base = {
        'neuilly': 80,
        'paris': 70,
        'montpellier': 60,
        'toulouse': 50,
        'lyon': 90
    }

    coquetterie_base = {
        'neuilly': 90,
        'paris': 75,
        'lyon': 60,
        'montpellier': 45,
        'toulouse': 30
    }

    # Génération des variables avec effets
    df['niveau_bolas'] = df['ville'].apply(lambda v: bolas_base[v] + np.random.normal(0, 10))
    df['niveau_bolas'] = df['niveau_bolas'].clip(0, 100)

    df['appetance_kro'] = df['niveau_bolas'] + np.random.normal(0, 10, size=n)
    df['appetance_kro'] = df['appetance_kro'].clip(0, 100)

    df['niveau_classe'] = df['ville'].apply(lambda v: classe_base[v] + np.random.normal(0, 10))
    df['niveau_classe'] = df['niveau_classe'].clip(0, 100)

    df['niveau_coquetterie'] = df['ville'].apply(lambda v: coquetterie_base[v] + np.random.normal(0, 10))
    df['niveau_coquetterie'] = df['niveau_coquetterie'].clip(0, 100)

    # Nouvel effet de ville
    ville_base_code = {
        'neuilly': 10,
        'paris': 20,
        'lyon': 30,
        'montpellier': 40,
        'toulouse': 50
    }

    df['niveau_code'] = df.apply(
        lambda row: (
            0.5 * row['niveau_classe'] -                # corrélation positive
            0.4 * row['niveau_coquetterie'] +           # corrélation négative
            ville_base_code[row['ville']] +             # effet de la ville
            np.random.normal(0, 5)                      # bruit
        ),
        axis=1
    )

    df['niveau_code'] = df['niveau_code'].clip(0, 100)

    return df


# Exemple d'utilisation
df_code = generate_habitants_data()
df_code
# Out:
#            ville  niveau_bolas  appetance_kro  niveau_classe  \
# 0    montpellier     63.723952      55.011483      56.896544
# 1        neuilly     23.415908      21.148414      81.156848
# 2          paris     56.188862      48.477997      57.490037
# 3        neuilly     35.465368      41.227114     100.000000
# 4        neuilly     10.504810      22.400807      72.670599
# ..           ...           ...            ...            ...
# 295      neuilly     21.274344      21.387829      81.777559
# 296      neuilly     28.668491      31.338994      75.322872
# 297        paris     39.710368      47.054896      87.911438
# 298  montpellier     61.417908      58.584755      61.739080
# 299     toulouse     89.018634      90.239174      60.894367
#
#      niveau_coquetterie  niveau_code
# 0             39.835511    52.422323
# 1             90.442439    20.960368
# 2             62.626584    18.950776
# 3             96.292490    10.673777
# 4             91.909378    11.403834
# ..                  ...          ...
# 295           91.666528    16.329535
# 296           93.251768    12.597525
# 297           73.332760    28.552978
# 298           53.089292    59.353208
# 299           22.895475    63.174438
#
# [300 rows x 6 columns]

# %%
df_code.to_excel('df_classecoquetterie.xlsx', index=False)

# %% [markdown]
# # Exercice
#
# Etude sur la différence entre la classe et la coquetterie ?

# %% [markdown]
# # La version bayésienne avec PyMC

# %%
import pymc as pm
import arviz as az
import numpy as np

# %%
# Préparation des données
X = df_raw["Wealth"].values
y = df_raw["Instruction"].values
regions = df_raw["Region"].astype("category").cat.codes.values
n_regions = len(df_raw["Region"].unique())

# Modèle PyMC
with pm.Model() as hierarchical_model:
    # Hyperpriors pour les effets aléatoires
    mu_region = pm.Normal("mu_region", mu=0, sigma=10)
    sigma_region = pm.HalfNormal("sigma_region", sigma=1)

    # Effets aléatoires par région
    region = pm.Normal("region", mu=mu_region, sigma=sigma_region, shape=n_regions)

    # Priors pour les coefficients fixes
    beta_wealth = pm.Normal("beta_wealth", mu=0, sigma=10)
    sigma = pm.HalfNormal("sigma", sigma=1)

    # Modèle linéaire
    mu = region[regions] + beta_wealth * X
    likelihood = pm.Normal("y", mu=mu, sigma=sigma, observed=y)

    # Inférence
    trace = pm.sample(2000, tune=1000, chains=2)

# Résumé
az.summary(trace)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [mu_region, sigma_region, region, beta_wealth, sigma]
# Output()
# /home/alex/Bureau/Formation_2026_Python/env_formation/lib/python3.13/site-packages/pymc/step_methods/hmc/quadpotential.py:316: RuntimeWarning: overflow encountered in dot
#   return 0.5 * np.dot(x, v_out)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 13 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
#                 mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# mu_region     30.042  3.384  23.564   36.285      0.076    0.050    1981.0
# region[0]     46.739  3.325  40.580   52.915      0.080    0.046    1719.0
# region[1]     11.433  3.421   5.133   17.788      0.080    0.049    1839.0
# region[2]     18.953  2.745  14.056   24.477      0.053    0.043    2637.0
# region[3]     37.953  3.251  32.042   44.454      0.080    0.051    1667.0
# region[4]     44.377  3.476  38.217   51.321      0.082    0.051    1787.0
# beta_wealth    0.254  0.049   0.165    0.349      0.001    0.001    1305.0
# sigma_region   5.559  0.567   4.485    6.618      0.009    0.009    3542.0
# sigma         10.766  0.436   9.947   11.598      0.007    0.007    4219.0
#
#               ess_tail  r_hat
# mu_region       2667.0    1.0
# region[0]       2365.0    1.0
# region[1]       2215.0    1.0
# region[2]       2582.0    1.0
# region[3]       2500.0    1.0
# region[4]       2455.0    1.0
# beta_wealth     2129.0    1.0
# sigma_region    2740.0    1.0
# sigma           2937.0    1.0

# %%
az.plot_trace(trace)

# %%
trace_renamed = trace_renamed.assign_coords({"region_lab": ["Nord", "Sud", "Est", "Ouest", "Centre"]})
az.plot_forest(trace_renamed, var_names=["region"], combined=True)
# Out:
# array([<Axes: title={'center': '94.0% HDI'}>], dtype=object)
